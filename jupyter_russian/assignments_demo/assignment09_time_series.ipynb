# %% [markdown]
# <center>
# <img src="../../img/ods_stickers.jpg">
# ## Открытый курс по машинному обучению
# Автор материала: Мария Мансурова, аналитик-разработчик в команде Яндекс.Метрики
#
# Материал распространяется на условиях лицензии [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/). Можно использовать в любых целях (редактировать, поправлять и брать за основу), кроме коммерческих, но с обязательным упоминанием автора материала.

# %% [markdown]
# # <center> Домашнее задание № 9. (демо)
# ## <center> Анализ временных рядов
#
# **Заполните пропущенный код и ответьте на вопросы в [онлайн-форме](https://docs.google.com/forms/d/1ijk4aFKY5plPiI8z3Mgi3i1Ln94VBY9SSt6xGIdVVFQ/).**

# %%
import numpy as np
import pandas as pd
import os

from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly import graph_objs as go
import requests

print(__version__) # need 1.9.0 or greater

init_notebook_mode(connected = True)

def plotly_df(df, title = ''):
    data = []
    
    for column in df.columns:
        trace = go.Scatter(
            x = df.index,
            y = df[column],
            mode = 'lines',
            name = column
        )
        data.append(trace)
    
    layout = dict(title = title)
    fig = dict(data = data, layout = layout)
    iplot(fig, show_link=False)
# Out:
# 4.9.0
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Подготавливаем данные
#
# Для начала скачаем данные в `dataframe`. Сегодня будем предсказывать просмотры wiki-страницы [Machine Learning](https://en.wikipedia.org/wiki/Machine_learning). Данные я скачала с помощью библиотеки [Wikipediatrend](https://www.r-bloggers.com/using-wikipediatrend/) для `R`.

# %%
df = pd.read_csv('../../data/wiki_machine_learning.csv', sep = ' ')
df = df[df['count'] != 0]
df.head()
# Out:
#           date  count lang              page  rank   month             title
# 81  2015-01-01   1414   en  Machine_learning  8708  201501  Machine_learning
# 80  2015-01-02   1920   en  Machine_learning  8708  201501  Machine_learning
# 79  2015-01-03   1338   en  Machine_learning  8708  201501  Machine_learning
# 78  2015-01-04   1404   en  Machine_learning  8708  201501  Machine_learning
# 77  2015-01-05   2264   en  Machine_learning  8708  201501  Machine_learning

# %%
df.shape
# Out:
# (383, 7)

# %%
df.date = pd.to_datetime(df.date)

# %%
plotly_df(df.set_index('date')[['count']])
# Out:
# <div>
#
#
#             <div id="252cb284-2a7d-4c33-95ec-12cce5edf9c9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("252cb284-2a7d-4c33-95ec-12cce5edf9c9")) {
#                     Plotly.newPlot(
#                         '252cb284-2a7d-4c33-95ec-12cce5edf9c9',
#                         [{"mode": "lines", "name": "count", "type": "scatter", "x": ["2015-01-01T00:00:00", "2015-01-02T00:00:00", "2015-01-03T00:00:00", "2015-01-04T00:00:00", "2015-01-05T00:00:00", "2015-01-06T00:00:00", "2015-01-07T00:00:00", "2015-01-08T00:00:00", "2015-01-09T00:00:00", "2015-01-10T00:00:00", "2015-01-11T00:00:00", "2015-01-12T00:00:00", "2015-01-13T00:00:00", "2015-01-14T00:00:00", "2015-01-15T00:00:00", "2015-01-16T00:00:00", "2015-01-17T00:00:00", "2015-01-18T00:00:00", "2015-01-19T00:00:00", "2015-01-20T00:00:00", "2015-01-21T00:00:00", "2015-01-22T00:00:00", "2015-01-23T00:00:00", "2015-01-24T00:00:00", "2015-01-25T00:00:00", "2015-01-26T00:00:00", "2015-01-27T00:00:00", "2015-01-28T00:00:00", "2015-01-29T00:00:00", "2015-01-30T00:00:00", "2015-01-31T00:00:00", "2015-02-01T00:00:00", "2015-02-02T00:00:00", "2015-02-03T00:00:00", "2015-02-04T00:00:00", "2015-02-06T00:00:00", "2015-02-07T00:00:00", "2015-02-08T00:00:00", "2015-02-09T00:00:00", "2015-02-10T00:00:00", "2015-02-11T00:00:00", "2015-02-12T00:00:00", "2015-02-13T00:00:00", "2015-02-14T00:00
2015-06-03T00:00:00", "2015-06-04T00:00:00", "2015-06-05T00:00:00", "2015-06-06T00:00:00", "2015-06-07T00:00:00", "2015-06-08T00:00:00", "2015-06-09T00:00:00", "2015-06-10T00:00:00", "2015-06-11T00:00:00", "2015-06-12T00:00:00", "2015-06-13T00:00:00", "2015-06-14T00:00:00", "2015-06-15T00:00:00", "2015-06-16T00:00:00", "2015-06-17T00:00:00", "2015-06-18T00:00:00", "2015-06-19T00:00:00", "2015-06-20T00:00:00", "2015 ...

# %% [markdown]
# ## Предсказание с помощью Facebook Prophet
#
# Для начала построим предсказание с помощью простой библиотеки `Facebook Prophet`. Для того, чтобы посмотреть на качество модели, отбросим из обучающей выборки последние 30 дней.

# %%
from fbprophet import Prophet
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-f503e9c6cf11> in <module>
# ----> 1 from fbprophet import Prophet
#
# ModuleNotFoundError: No module named 'fbprophet'

# %%
predictions = 30

df = df[['date', 'count']]
df.columns = ['ds', 'y']
train_df = df[:-predictions].copy()

# %%
df.tail()
# Out:
#             ds     y
# 382 2016-01-16  1644
# 381 2016-01-17  1836
# 376 2016-01-18  2983
# 375 2016-01-19  3389
# 372 2016-01-20  3559

# %%
## ВАШ КОД для построения модели ##
m = Prophet()
m.fit(train_df);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-2145effe7911> in <module>
#       1 ## ВАШ КОД для построения модели ##
# ----> 2 m = Prophet()
#       3 m.fit(train_df);
#
# NameError: name 'Prophet' is not defined

# %%
future = m.make_future_dataframe(periods=predictions)
future.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-6382b5ed7996> in <module>
# ----> 1 future = m.make_future_dataframe(periods=predictions)
#       2 future.tail()
#
# NameError: name 'm' is not defined

# %%
forecast = m.predict(future)
forecast.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-d9e06e1d059c> in <module>
# ----> 1 forecast = m.predict(future)
#       2 forecast.tail()
#
# NameError: name 'm' is not defined

# %% [markdown]
# **Вопрос 1:** Какое предсказание числа просмотров wiki-страницы на 20 января? Ответ округлите до целого числа.
#
# Оценим качество предсказания по последним 30 точкам.

# %%
## ВАШ КОД для оценки качества полученной модели ##
m.plot(forecast)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-31166829ba91> in <module>
#       1 ## ВАШ КОД для оценки качества полученной модели ##
# ----> 2 m.plot(forecast)
#
# NameError: name 'm' is not defined

# %%
m.plot_components(forecast)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-cfc41cac3540> in <module>
# ----> 1 m.plot_components(forecast)
#
# NameError: name 'm' is not defined

# %%
cmp_df = forecast.set_index('ds')[['yhat', 'yhat_lower', 'yhat_upper']].join(df.set_index('ds'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-f03658b0ce5e> in <module>
# ----> 1 cmp_df = forecast.set_index('ds')[['yhat', 'yhat_lower', 'yhat_upper']].join(df.set_index('ds'))
#
# NameError: name 'forecast' is not defined

# %%
cmp_df['e'] = cmp_df['y'] - cmp_df['yhat']
cmp_df['p'] = 100 * cmp_df['e'] / cmp_df['y']
print('MAPE = ', round(np.mean(abs(cmp_df[-predictions:]['p'])), 2))
print('MAE = ', round(np.mean(abs(cmp_df[-predictions:]['e'])), 2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-d12164ad63e5> in <module>
# ----> 1 cmp_df['e'] = cmp_df['y'] - cmp_df['yhat']
#       2 cmp_df['p'] = 100 * cmp_df['e'] / cmp_df['y']
#       3 print('MAPE = ', round(np.mean(abs(cmp_df[-predictions:]['p'])), 2))
#       4 print('MAE = ', round(np.mean(abs(cmp_df[-predictions:]['e'])), 2))
#
# NameError: name 'cmp_df' is not defined

# %% [markdown]
# **Вопрос 2**: Какое получилось MAPE?
#
# **Вопрос 3**: Какое получилось MAE?

# %% [markdown]
# ## Предсказываем с помощью ARIMA

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.api as sm

# %% [markdown]
# **Вопрос 4:** Проверим стационарность ряда с помощью критерия Дики-Фулера. Является ли ряд стационарным? Какое значение p-value?

# %%
## ВАШ КОД для проверки стационарности ряда ##
sm.tsa.seasonal_decompose(train_df['y'].values, freq=7).plot();
print("Dickey-Fuller test: p=%f" % sm.tsa.stattools.adfuller(train_df['y'])[1])
# Out:
# D:\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning:
#
# the 'freq'' keyword is deprecated, use 'period' instead
# Dickey-Fuller test: p=0.107392

# %%
train_df.set_index('ds', inplace=True)

# %%
train_df['y_diff'] = train_df.y - train_df.y.shift(7)
sm.tsa.seasonal_decompose(train_df.y_diff[7:].values, freq=7).plot();
print("Dickey-Fuller test: p=%f" % sm.tsa.stattools.adfuller(train_df.y_diff[8:])[1])
# Out:
# D:\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning:
#
# the 'freq'' keyword is deprecated, use 'period' instead
# Dickey-Fuller test: p=0.000000

# %%
ax = plt.subplot(211)
sm.graphics.tsa.plot_acf(train_df.y_diff[13:].values.squeeze(), lags=48, ax=ax)

ax = plt.subplot(212)
sm.graphics.tsa.plot_pacf(train_df.y_diff[13:].values.squeeze(), lags=48, ax=ax)

# %%
ps = range(0, 2)
ds = range(0, 2)
qs = range(0, 4)
Ps = range(0, 4)
Ds = range(0, 3)
Qs = range(0, 2)

# %%
from itertools import product

parameters = product(ps, ds, qs, Ps, Ds, Qs)
parameters_list = list(parameters)
len(parameters_list)
# Out:
# 384

# %%
# %%time
import warnings
from tqdm import tqdm
results1 = []
best_aic = float("inf")
warnings.filterwarnings('ignore')

for param in tqdm(parameters_list):
    #try except is necessary, because on some sets of parameters the model can not be trained
    try:
        model=sm.tsa.statespace.SARIMAX(train_df['y'], order=(param[0], param[1], param[2]), 
                                        seasonal_order=(param[3], param[4], param[5], 7)).fit(disp=-1)
    #print parameters on which the model is not trained and proceed to the next set
    except (ValueError, np.linalg.LinAlgError):
        continue
    aic = model.aic
    #save the best model, aic, parameters
    if aic < best_aic:
        best_model = model
        best_aic = aic
        best_param = param
    results1.append([param, model.aic])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 384/384 [11:45<00:00,  1.84s/it]
# Wall time: 11min 45s

# %%
result_table1 = pd.DataFrame(results1)
result_table1.columns = ['parameters', 'aic']
print(result_table1.sort_values(by = 'aic', ascending=True).head())
# Out:
#              parameters          aic
# 163  (0, 1, 2, 3, 2, 1)  4961.632628
# 330  (1, 1, 1, 3, 2, 1)  4962.865335
# 378  (1, 1, 3, 3, 2, 1)  4965.670283
# 187  (0, 1, 3, 3, 2, 1)  4969.534604
# 210  (1, 0, 0, 3, 2, 1)  4973.212241

# %%
## ВАШ КОД для построения модели ##
result_table1[result_table1['parameters'].isin([(1, 0, 2, 3, 1, 0),
                                                (1, 1, 2, 3, 2, 1),
                                                (1, 1, 2, 3, 1, 1),
                                                (1, 0, 2, 3, 0, 0)])]
# Out:
#              parameters          aic
# 253  (1, 0, 2, 3, 0, 0)  5183.801982
# 255  (1, 0, 2, 3, 1, 0)  5022.312525
# 352  (1, 1, 2, 3, 1, 1)  5019.555903
# 354  (1, 1, 2, 3, 2, 1)  4988.979200

# %%
import scipy.stats
train_df['y_box'], lmbda = scipy.stats.boxcox(train_df['y']) 
print("The optimal Box-Cox transformation parameter: %f" % lmbda)
# Out:
# The optimal Box-Cox transformation parameter: 0.732841

# %%
results2 = []
best_aic = float("inf")

for param in tqdm(parameters_list):
    #try except is necessary, because on some sets of parameters the model can not be trained
    try:
        model=sm.tsa.statespace.SARIMAX(train_df['y_box'], order=(param[0], param[1], param[2]), 
                                        seasonal_order=(param[3], param[4], param[5], 7)).fit(disp=-1)
    #print parameters on which the model is not trained and proceed to the next set
    except (ValueError, np.linalg.LinAlgError):
        continue
    aic = model.aic
    #save the best model, aic, parameters
    if aic < best_aic:
        best_model = model
        best_aic = aic
        best_param = param
    results2.append([param, model.aic])
    
warnings.filterwarnings('default')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 384/384 [09:10<00:00,  1.43s/it]

# %%
result_table2 = pd.DataFrame(results2)
result_table2.columns = ['parameters', 'aic']
print(result_table2.sort_values(by = 'aic', ascending=True).head())
# Out:
#              parameters          aic
# 259  (1, 0, 2, 3, 2, 1)  3528.650817
# 212  (1, 0, 0, 3, 2, 1)  3530.524249
# 379  (1, 1, 3, 3, 2, 1)  3531.815034
# 235  (1, 0, 1, 3, 2, 1)  3532.092280
# 331  (1, 1, 1, 3, 2, 1)  3534.434779

# %%
result_table2[result_table2['parameters'].isin([(1, 0, 2, 3, 1, 0),
                                                (1, 1, 2, 3, 2, 1),
                                                (1, 1, 2, 3, 1, 1),
                                                (1, 0, 2, 3, 0, 0)])].sort_values(by='aic')
# Out:
#              parameters          aic
# 355  (1, 1, 2, 3, 2, 1)  3534.540192
# 256  (1, 0, 2, 3, 1, 0)  3556.880030
# 353  (1, 1, 2, 3, 1, 1)  3557.857479
# 254  (1, 0, 2, 3, 0, 0)  3674.916100

# %% [markdown]
# **Вопрос 5**: Далее перейдем к построению модели SARIMAX (`sm.tsa.statespace.SARIMAX`). Модель c какими параметрами лучшая по `AIC`-критерию?

# %%
print(best_model.summary())
# Out:
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                               y_box   No. Observations:                  353
# Model:             SARIMAX(1, 0, 2)x(3, 2, [1], 7)   Log Likelihood               -1756.325
# Date:                             Wed, 19 Aug 2020   AIC                           3528.651
# Time:                                     04:40:46   BIC                           3559.259
# Sample:                                          0   HQIC                          3540.848
#                                              - 353
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8196      0.118      6.961      0.000       0.589       1.050
# ma.L1         -0.3354      0.124     -2.703      0.007      -0.579      -0.092
# ma.L2         -0.2022      0.091     -2.222      0.026      -0.381      -0.024
# ar.S.L7       -0.6465      0.039    -16.432      0.000      -0.724      -0.569
# ar.S.L14      -0.4304      0.059     -7.333      0.000      -0.545      -0.315
# ar.S.L21      -0.2662      0.043     -6.186      0.000      -0.351      -0.182
# ma.S.L7       -0.9996      3.028     -0.330      0.741      -6.934       4.935
# sigma2      1632.8125   4924.727      0.332      0.740   -8019.475    1.13e+04
# ===================================================================================
# Ljung-Box (Q):                       52.85   Jarque-Bera (JB):               528.24
# Prob(Q):                              0.08   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.74   Skew:                             0.95
# Prob(H) (two-sided):                  0.12   Kurtosis:                         8.81
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
plt.subplot(211)
best_model.resid[13:].plot()
plt.ylabel(u'Residuals')

ax = plt.subplot(212)
sm.graphics.tsa.plot_acf(best_model.resid[13:].values.squeeze(), lags=48, ax=ax)

print("Student's test: p=%f" % stats.ttest_1samp(best_model.resid[13:], 0)[1])
print("Dickey-Fuller test: p=%f" % sm.tsa.stattools.adfuller(best_model.resid[13:])[1])
# Out:
# Student's test: p=0.114831
# Dickey-Fuller test: p=0.000000

# %%
def invboxcox(y,lmbda):
    # reverse Box Cox transformation
    if lmbda == 0:
        return(np.exp(y))
    else:
        return(np.exp(np.log(lmbda * y + 1) / lmbda))

# %%
train_df['arima_model'] = invboxcox(best_model.fittedvalues, lmbda)

train_df.y.tail(200).plot()
train_df.arima_model[13:].tail(200).plot(color='r')
plt.ylabel('wiki pageviews');
